# %% [markdown]
# # Energy Deposition in LArTPC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cosmicFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/cosmicEFrac.csv'
signalFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/nueArCCSignalEFrac.csv'
nueOutFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/nueArCCoutFiducialEFrac.csv'

# %%
cosmic = pd.read_csv( cosmicFile )
signal = pd.read_csv( signalFile )
nueOut = pd.read_csv( nueOutFile )

# %%
cosmic
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE       MaxE  \
# 0        0    251   0.000000  0.000000  0.084589  0.084589   0.069128
# 1        0    364   0.000000  0.000000  0.392915  0.392915  15.625915
# 2        0    390   0.000000  0.000000  0.148901  0.148901   0.126668
# 3        0    480   0.000000  0.000000  0.334323  0.334323  18.008526
# 4        0    796   0.073977  0.058413  0.000000  0.132390   0.073977
# ...    ...    ...        ...       ...       ...       ...        ...
# 8539  2498    820   0.000000  0.000000  0.302879  0.302879   0.220526
# 8540  2498    899   0.000000  0.000000  0.053708  0.053708   0.053708
# 8541  2499    151   0.268691  0.039755  0.054821  0.363267   0.155253
# 8542  2499    184   0.000000  0.000000  0.216438  0.216438   0.119791
# 8543  2499    562   0.679984  0.000000  0.910751  1.590734   0.641247
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE   LeftCRTE  RightCRTE
# 0      0.000000    0.000000   0.000000  0.000000   0.000000   0.000000
# 1     11.101328    0.000000   0.000000  0.000000  13.193037   0.341808
# 2      5.847214    8.366082   0.018158  0.581913   0.000000   0.000000
# 3      5.702259    5.616968   0.000000  0.000000   0.000000   0.000000
# 4      0.007804    0.000000   0.000000  0.000000   0.000000   2.125036
# ...         ...         ...        ...       ...        ...        ...
# 8539   0.000000    0.000000   0.000000  0.000000   0.000000   0.000000
# 8540   0.000000    0.000000   1.202076  0.000000   0.000000   0.000000
# 8541   0.000000    0.000000   0.000000  0.000000   0.000000   0.017279
# 8542   0.000000    0.000000   0.000000  9.305169   7.483774   0.000000
# 8543   6.513887    0.000000   0.000000  0.000000   0.000000   0.000000
#
# [8544 rows x 13 columns]

# %%
signal
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0        0      0   0.000000   0.026611  18.707125  18.733736  15.237371
# 1        0      1   0.000000   7.279029  11.526980  18.806009  15.743186
# 2        0      2   1.547156   6.588975  26.289853  34.425985  25.637749
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022   0.113112  40.811681  29.338700
# ...    ...    ...        ...        ...        ...        ...        ...
# 99995    9   9995  28.784116   2.695864   0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE
# 0          0.0    0.000000   0.170640  0.000000  0.000000   0.288692
# 1          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 2          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 3          0.0    0.005238   0.000000  0.004326  0.000000   0.000000
# 4          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# ...        ...         ...        ...       ...       ...        ...
# 99995      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99996      0.0    0.454136   0.000000  0.000000  0.148523   0.000000
# 99997      0.0    0.000000   1.777848  0.000000  0.000000   0.000000
# 99998      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99999      0.0    0.000000   0.000000  0.000000  0.000000   0.233162
#
# [100000 rows x 13 columns]

# %%
cosmic['SignalVolEFrac'] = ( cosmic.FiducialE + cosmic.PartConE )/ cosmic.TotalE
cosmic
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE       MaxE  \
# 0        0    251   0.000000  0.000000  0.084589  0.084589   0.069128
# 1        0    364   0.000000  0.000000  0.392915  0.392915  15.625915
# 2        0    390   0.000000  0.000000  0.148901  0.148901   0.126668
# 3        0    480   0.000000  0.000000  0.334323  0.334323  18.008526
# 4        0    796   0.073977  0.058413  0.000000  0.132390   0.073977
# ...    ...    ...        ...       ...       ...       ...        ...
# 8539  2498    820   0.000000  0.000000  0.302879  0.302879   0.220526
# 8540  2498    899   0.000000  0.000000  0.053708  0.053708   0.053708
# 8541  2499    151   0.268691  0.039755  0.054821  0.363267   0.155253
# 8542  2499    184   0.000000  0.000000  0.216438  0.216438   0.119791
# 8543  2499    562   0.679984  0.000000  0.910751  1.590734   0.641247
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE   LeftCRTE  RightCRTE  \
# 0      0.000000    0.000000   0.000000  0.000000   0.000000   0.000000
# 1     11.101328    0.000000   0.000000  0.000000  13.193037   0.341808
# 2      5.847214    8.366082   0.018158  0.581913   0.000000   0.000000
# 3      5.702259    5.616968   0.000000  0.000000   0.000000   0.000000
# 4      0.007804    0.000000   0.000000  0.000000   0.000000   2.125036
# ...         ...         ...        ...       ...        ...        ...
# 8539   0.000000    0.000000   0.000000  0.000000   0.000000   0.000000
# 8540   0.000000    0.000000   1.202076  0.000000   0.000000   0.000000
# 8541   0.000000    0.000000   0.000000  0.000000   0.000000   0.017279
# 8542   0.000000    0.000000   0.000000  9.305169   7.483774   0.000000
# 8543   6.513887    0.000000   0.000000  0.000000   0.000000   0.000000
#
#       SignalVolEFrac
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           1.000000
# ...              ...
# 8539        0.000000
# 8540        0.000000
# 8541        0.849090
# 8542        0.000000
# 8543        0.427465
#
# [8544 rows x 14 columns]

# %%
signal['SignalVolEFrac'] = ( signal.FiducialE + signal.PartConE )/ signal.TotalE
nueOut['SignalVolEFrac'] = ( nueOut.FiducialE + nueOut.PartConE )/ nueOut.TotalE

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( nueOut.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Fraction in the Signal Volume')
    iax.set_xlim([0, 1])
    iax.grid(':')
    iax.legend( loc = 'upper center')

# %%
fig, ax = plt.subplots( figsize = (8, 6) )

ax.hist( signal.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, 
        label = r'$\nu_e$-Ar CC Signal' )
ax.hist( cosmic.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2,
        label = 'Cosmic' )
ax.hist( nueOut.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.',
        label = r'$\nu_e$-Ar CC Outside' )

ax.set_xlabel( 'Deposited Energy Fraction in the Signal Volume', fontsize = 16)
ax.set_ylabel( 'Arbitray Unit', fontsize = 16)
ax.tick_params( axis = 'x', labelsize = 16)
ax.tick_params( axis = 'y', labelsize = 16)

ax.set_xlim([ 0, 1 ])
ax.grid(':')
ax.legend(fontsize = 16)

# fig.savefig('EFraction.pdf')

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.OutE>1)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE      TotalE        MaxE  \
# 50      10    185   0.924879   1.311020   1.958516    4.194415    1.147575
# 78      18    699   0.000000  87.338701  33.748261  121.086961  118.099508
# 80      19     83   0.000000  12.976906   1.685846   14.662752    6.968210
# 85      19    787   0.000000   4.522047   1.259058    5.781105    5.461302
# 110     27    216   0.152494   5.007660   1.737041    6.897194    4.188125
# ...    ...    ...        ...        ...        ...         ...         ...
# 8478  2483    695   0.574152   2.641302   3.755894    6.971348    3.547314
# 8482  2484    343   0.000000   1.739496   2.476967    4.216464    2.923778
# 8501  2488    752   0.810198   0.778797   1.447286    3.036282    0.683563
# 8508  2491    235   0.000000  26.512825  17.558532   44.071357   45.747845
# 8523  2496    109   3.379363   0.104562   1.956697    5.440622    2.114657
#
#        TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 50    7.539111    6.501373  14.112624  0.000000  0.103852   0.010992
# 78    5.907705    4.798598   0.000000  0.000000  0.000000   0.000000
# 80    0.279232    6.655934   0.000000  0.000000  0.000000  11.533876
# 85    0.000000    0.000000   0.000000  0.000000  0.000000   0.000000
# 110   9.514793    0.000000   0.000000  0.071135  0.000000   0.000000
# ...        ...         ...        ...       ...       ...        ...
# 8478  4.917829    6.957300   0.000000  0.000000  0.181736   0.000000
# 8482  0.000000    0.000000   0.000000  0.000000  0.000000   0.000000
# 8501  6.809644    0.000000   0.000000  0.810630  0.394320   0.000000
# 8508  7.038449    0.000000   0.000000  0.000000  0.000000   0.000000
# 8523  0.000000    0.000000   0.000000  0.000000  0.000000   0.000000
#
#       SignalVolEFrac
# 50          0.533066
# 78          0.721289
# 80          0.885025
# 85          0.782211
# 110         0.748153
# ...              ...
# 8478        0.461238
# 8482        0.412549
# 8501        0.523336
# 8508        0.601589
# 8523        0.640354
#
# [331 rows x 14 columns]

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.OutE>1)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 6        0      6   0.844765  31.629057   1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413   8.276063  25.888491  17.328523
# 10       0     10   0.010894  34.610286   8.084882  42.706062  23.507860
# 12       0     12   1.143909  39.672094   1.454672  42.270675  28.521956
# 13       0     13   1.771562  34.814713   5.994312  42.580586  16.858767
# ...    ...    ...        ...        ...        ...        ...        ...
# 99987    9   9987  33.439328   2.377019   1.369508  37.185855  18.064338
# 99988    9   9988   0.467621  25.133688   3.643370  29.244679  25.985487
# 99992    9   9992   7.769625  11.877627  12.659921  32.307172  27.431598
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 6      0.000000         0.0   0.000000       0.0  0.000000        0.0
# 7      0.000000         0.0   0.000000       0.0  0.000000        0.0
# 10     0.000000         0.0   0.000000       0.0  0.058936        0.0
# 12     0.078964         0.0   0.000000       0.0  0.000000        0.0
# 13     0.000000         0.0   0.000000       0.0  0.000000        0.0
# ...         ...         ...        ...       ...       ...        ...
# 99987  0.000000         0.0   0.000000       0.0  0.000000        0.0
# 99988  0.000000         0.0   0.000000       0.0  0.000000        0.0
# 99992  0.000000         0.0   0.000000       0.0  0.216049        0.0
# 99997  0.000000         0.0   1.777848       0.0  0.000000        0.0
# 99998  0.000000         0.0   0.000000       0.0  0.000000        0.0
#
#        SignalVolEFrac
# 6            0.956989
# 7            0.680319
# 10           0.810685
# 12           0.965587
# 13           0.859224
# ...               ...
# 99987        0.963171
# 99988        0.875418
# 99992        0.608139
# 99997        0.941688
# 99998        0.965836
#
# [40159 rows x 14 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( nueOut.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited outside the Signal Volume')
    iax.set_xlim([0, 10])
    iax.grid(':')
    iax.legend()

# %%
cosmic['SignalVolE'] = cosmic.FiducialE + cosmic.PartConE
signal['SignalVolE'] = signal.FiducialE + signal.PartConE
nueOut['SignalVolE'] = nueOut.FiducialE + nueOut.PartConE

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( nueOut.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the Signal Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( nueOut.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the TPC Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.SignalVolE>5)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057  1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 3          0.0    0.005238   0.000000  0.004326  0.000000   0.000000
# 4          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 5          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 6          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 7          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# ...        ...         ...        ...       ...       ...        ...
# 99995      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99996      0.0    0.454136   0.000000  0.000000  0.148523   0.000000
# 99997      0.0    0.000000   1.777848  0.000000  0.000000   0.000000
# 99998      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99999      0.0    0.000000   0.000000  0.000000  0.000000   0.233162
#
#        SignalVolEFrac  SignalVolE
# 3            0.990078   29.296249
# 4            0.997228   40.698568
# 5            0.990654   37.999851
# 6            0.956989   32.473822
# 7            0.680319   17.612428
# ...               ...         ...
# 99995        0.982545   31.479980
# 99996        0.976469   20.090197
# 99997        0.941688   25.256168
# 99998        0.965836   36.755376
# 99999        0.974298   17.374711
#
# [87398 rows x 15 columns]

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.SignalVolE>5)]
# Out:
#        Run  Event  FiducialE    PartConE       OutE      TotalE        MaxE  \
# 53      11    123   7.978759    0.145265   0.134800    8.258825    5.212990
# 78      18    699   0.000000   87.338701  33.748261  121.086961  118.099508
# 80      19     83   0.000000   12.976906   1.685846   14.662752    6.968210
# 110     27    216   0.152494    5.007660   1.737041    6.897194    4.188125
# 148     39    162   4.541694    0.551072   7.412122   12.504888    3.895339
# ...    ...    ...        ...         ...        ...         ...         ...
# 8311  2436    426  10.592042    0.323491   2.144363   13.059896    5.799050
# 8329  2440    608   0.054889  101.803014  30.151268  132.009171  117.648070
# 8429  2468     18   0.000000   18.229334   0.839664   19.068998   16.213245
# 8463  2478     74   5.350345    2.315919   1.601035    9.267298    4.986290
# 8508  2491    235   0.000000   26.512825  17.558532   44.071357   45.747845
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 53     0.000000    9.618395  12.731857  0.000000  0.000000   1.708543
# 78     5.907705    4.798598   0.000000  0.000000  0.000000   0.000000
# 80     0.279232    6.655934   0.000000  0.000000  0.000000  11.533876
# 110    9.514793    0.000000   0.000000  0.071135  0.000000   0.000000
# 148   27.221760    6.381828   0.062803  0.119215  0.000000   5.314547
# ...         ...         ...        ...       ...       ...        ...
# 8311  11.056007    0.000000  33.482896  0.000000  0.164861   0.000000
# 8329   5.637289   11.433212   0.000000  0.000000  0.000000   6.108981
# 8429   7.490535    0.000000   0.115063  0.185965  0.000000  42.452574
# 8463   5.693491   10.925234   0.000000  0.095124  0.325900   0.000000
# 8508   7.038449    0.000000   0.000000  0.000000  0.000000   0.000000
#
#       SignalVolEFrac  SignalVolE
# 53          0.983678    8.124024
# 78          0.721289   87.338701
# 80          0.885025   12.976906
# 110         0.748153    5.160153
# 148         0.407262    5.092767
# ...              ...         ...
# 8311        0.835806   10.915533
# 8329        0.771597  101.857903
# 8429        0.955967   18.229334
# 8463        0.827238    7.666263
# 8508        0.601589   26.512825
#
# [346 rows x 15 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( nueOut.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the Fiducial Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
cosmic['FiducialEFrac'] = cosmic.FiducialE / cosmic.TotalE
signal['FiducialEFrac'] = signal.FiducialE / signal.TotalE
nueOut['FiducialEFrac'] = nueOut.FiducialE / nueOut.TotalE

# %%
fig, ax = plt.subplots( figsize = (8, 6) )

ax.hist( signal.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, 
        label = r'$\nu_e$-Ar CC Signal' )
ax.hist( cosmic.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2,
        label = 'Cosmic' )
ax.hist( nueOut.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.',
        label = r'$\nu_e$-Ar CC Outside' )

ax.set_xlabel( 'Deposited Energy Fraction in the Fiducial Volume', fontsize = 16)
ax.set_ylabel( 'Arbitray Unit', fontsize = 16)
ax.tick_params( axis = 'x', labelsize = 16)
ax.tick_params( axis = 'y', labelsize = 16)

ax.set_xlim([ 0, 1 ])
ax.grid(':')
ax.legend(fontsize = 16)

# %%
cosmic[cosmic.FiducialEFrac>0.025]
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 4        0    796   0.073977  0.058413  0.000000  0.132390  0.073977
# 7        1    389   0.065921  0.113706  0.000000  0.179627  0.081084
# 8        1    505   0.406363  0.130759  0.321590  0.858713  0.360997
# 12       2     87   1.993693  1.132214  0.000000  3.125907  0.880995
# 28       6     21   0.497373  0.000000  0.106635  0.604007  0.216696
# ...    ...    ...        ...       ...       ...       ...       ...
# 8523  2496    109   3.379363  0.104562  1.956697  5.440622  2.114657
# 8531  2497    555   0.857987  0.942332  0.296239  2.096557  0.855674
# 8537  2498    718   1.961833  0.000000  0.100173  2.062006  1.936890
# 8541  2499    151   0.268691  0.039755  0.054821  0.363267  0.155253
# 8543  2499    562   0.679984  0.000000  0.910751  1.590734  0.641247
#
#         TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  LeftCRTE  RightCRTE  \
# 4      0.007804    0.000000   0.000000   0.000000  0.000000   2.125036
# 7      6.474688    7.243448   0.000000   1.058106  0.000000   0.000000
# 8      0.000000    0.000000   0.000000   0.000000  0.000000   0.000000
# 12     0.001873    6.262168   0.000000  28.405041  3.117162   0.000000
# 28    11.973503    0.000000  12.960834   0.000000  0.000000   0.777160
# ...         ...         ...        ...        ...       ...        ...
# 8523   0.000000    0.000000   0.000000   0.000000  0.000000   0.000000
# 8531   6.160233    0.000000   0.000000  18.887057  0.000000   0.185548
# 8537   0.007350    0.000000   0.000000   0.305657  0.000000   0.000000
# 8541   0.000000    0.000000   0.000000   0.000000  0.000000   0.017279
# 8543   6.513887    0.000000   0.000000   0.000000  0.000000   0.000000
#
#       SignalVolEFrac  SignalVolE  FiducialEFrac
# 4           1.000000    0.132390       0.558784
# 7           1.000000    0.179627       0.366987
# 8           0.625498    0.537123       0.473224
# 12          1.000000    3.125907       0.637797
# 28          0.823455    0.497373       0.823455
# ...              ...         ...            ...
# 8523        0.640354    3.483925       0.621135
# 8531        0.858702    1.800318       0.409236
# 8537        0.951420    1.961833       0.951420
# 8541        0.849090    0.308447       0.739652
# 8543        0.427465    0.679984       0.427465
#
# [1934 rows x 16 columns]

# %%
signal[signal.FiducialEFrac>0.025]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 2        0      2   1.547156   6.588975  26.289853  34.425985  25.637749
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022   0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787   0.358493  38.358345  27.304520
# 7        0      7   3.699015  13.913413   8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...        ...        ...        ...
# 99995    9   9995  28.784116   2.695864   0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 2          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 3          0.0    0.005238   0.000000  0.004326  0.000000   0.000000
# 4          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 5          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 7          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# ...        ...         ...        ...       ...       ...        ...
# 99995      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99996      0.0    0.454136   0.000000  0.000000  0.148523   0.000000
# 99997      0.0    0.000000   1.777848  0.000000  0.000000   0.000000
# 99998      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99999      0.0    0.000000   0.000000  0.000000  0.000000   0.233162
#
#        SignalVolEFrac  SignalVolE  FiducialEFrac
# 2            0.236337    8.136131       0.044942
# 3            0.990078   29.296249       0.868417
# 4            0.997228   40.698568       0.977062
# 5            0.990654   37.999851       0.984481
# 7            0.680319   17.612428       0.142883
# ...               ...         ...            ...
# 99995        0.982545   31.479980       0.898402
# 99996        0.976469   20.090197       0.733135
# 99997        0.941688   25.256168       0.026844
# 99998        0.965836   36.755376       0.774259
# 99999        0.974298   17.374711       0.965819
#
# [72412 rows x 16 columns]

# %%
nueOut[nueOut.FiducialEFrac>0.025]
# Out:
#         Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0         0      0   2.052607  10.040593  18.964540  31.057740  20.380514
# 1         0      1   0.424514   0.139770   0.202373   0.766656   0.157639
# 2         0      3   0.244532   0.220029   1.145129   1.609690   0.942383
# 3         0      4  18.804507  11.480983  14.173285  44.458775  16.678509
# 6         0      9   2.949516   0.475579   0.469707   3.894803   2.179923
# ...     ...    ...        ...        ...        ...        ...        ...
# 233509   39   9982   0.459121   0.249363   0.291606   1.000090   0.459121
# 233510   39   9983   1.864387   1.586496  18.264758  21.715641  11.815670
# 233511   39   9987   0.107435   0.953809   0.652256   1.713500   0.889359
# 233514   39   9991   0.083812   0.009544   1.999922   2.093278   1.555416
# 233516   39   9993   0.460785   0.405848   0.653404   1.520037   0.528793
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 0           0.0    0.000000   0.000000  2.514628  0.000000        0.0
# 1           0.0    0.000000   0.000000  0.000000  0.000000        0.0
# 2           0.0    0.000000   0.000000  0.000000  0.000000        0.0
# 3           0.0    0.000000   0.000000  0.000000  0.000000        0.0
# 6           0.0    0.000000   8.426954  0.000000  0.000000        0.0
# ...         ...         ...        ...       ...       ...        ...
# 233509      0.0    1.391402   0.000000  0.264380  0.000000        0.0
# 233510      0.0    0.000000   0.000000  0.000000  0.000000        0.0
# 233511      0.0    0.000000   0.000000  0.016776  0.000000        0.0
# 233514      0.0    0.000000   0.233634  0.000000  0.017094        0.0
# 233516      0.0    0.000000   0.000000  0.000000  0.061810        0.0
#
#         SignalVolEFrac  SignalVolE  FiducialEFrac
# 0             0.389378   12.093200       0.066090
# 1             0.736032    0.564283       0.553721
# 2             0.288603    0.464561       0.151912
# 3             0.681204   30.285490       0.422965
# 6             0.879401    3.425095       0.757295
# ...                ...         ...            ...
# 233509        0.708420    0.708483       0.459079
# 233510        0.158912    3.450883       0.085855
# 233511        0.619343    1.061244       0.062699
# 233514        0.044598    0.093355       0.040039
# 233516        0.570139    0.866633       0.303140
#
# [70005 rows x 16 columns]

# %%
pd.set_option('display.max_rows', 20)
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.FiducialEFrac>0.025)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.OutE>0.1)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 53      11    123   7.978759   0.145265   0.134800   8.258825   5.212990
# 203     54     31  10.160078  13.543609  24.842258  48.545946  11.464938
# 214     56    506   3.267359  24.038239  16.248782  43.554381  13.749409
# 606    165    573  11.816471  10.427630   7.918744  30.162846  13.987784
# 608    165    882   0.379938   6.537533   0.247291   7.164762   5.954936
# ...    ...    ...        ...        ...        ...        ...        ...
# 8128  2383    576   0.321676   6.981811   3.676333  10.979820  10.507671
# 8192  2406    768   4.313120  13.980253   1.229486  19.522859  10.042583
# 8223  2415    853  14.217589   7.339909  28.411064  49.968563  12.338942
# 8277  2426    648   5.401424  24.240384   4.497352  34.139160  12.042656
# 8311  2436    426  10.592042   0.323491   2.144363  13.059896   5.799050
#
#         TopCRTE  BottomCRTE  FrontCRTE   BackCRTE   LeftCRTE  RightCRTE  \
# 53     0.000000    9.618395  12.731857   0.000000   0.000000   1.708543
# 203   11.415215    0.000000  16.959919   0.000000   0.000000   0.000000
# 214   27.172707   12.569797   0.000000  85.089349   7.855768   0.000000
# 606    2.475566    0.000000   0.000000   0.000000   0.069314   0.000000
# 608    0.000000    0.000000   0.000000   0.000000   0.000000   0.000000
# ...         ...         ...        ...        ...        ...        ...
# 8128   0.000000    7.251512   0.000000   0.000000  28.333357   0.000000
# 8192   7.178637    3.469715   0.000000  25.849760   0.150972   0.000000
# 8223   0.023294    5.250846  18.422732   0.000000   0.000000   0.000000
# 8277  12.496288    0.000000   0.000000  18.813591   0.000000   0.000000
# 8311  11.056007    0.000000  33.482896   0.000000   0.164861   0.000000
#
#       SignalVolEFrac  SignalVolE  FiducialEFrac
# 53          0.983678    8.124024       0.966089
# 203         0.488273   23.703687       0.209288
# 214         0.626931   27.305599       0.075018
# 606         0.737467   22.244102       0.391756
# 608         0.965485    6.917471       0.053029
# ...              ...         ...            ...
# 8128        0.665174    7.303487       0.029297
# 8192        0.937023   18.293373       0.220927
# 8223        0.431421   21.557498       0.284531
# 8277        0.868264   29.641808       0.158218
# 8311        0.835806   10.915533       0.811036
#
# [82 rows x 16 columns]

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.FiducialEFrac>0.025)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.OutE>0.1)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# 8        0      8  13.741208  10.875554  0.129598  24.746360  13.717585
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 3          0.0    0.005238   0.000000  0.004326  0.000000   0.000000
# 4          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 5          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 7          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 8          0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# ...        ...         ...        ...       ...       ...        ...
# 99995      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99996      0.0    0.454136   0.000000  0.000000  0.148523   0.000000
# 99997      0.0    0.000000   1.777848  0.000000  0.000000   0.000000
# 99998      0.0    0.000000   0.000000  0.000000  0.000000   0.000000
# 99999      0.0    0.000000   0.000000  0.000000  0.000000   0.233162
#
#        SignalVolEFrac  SignalVolE  FiducialEFrac
# 3            0.990078   29.296249       0.868417
# 4            0.997228   40.698568       0.977062
# 5            0.990654   37.999851       0.984481
# 7            0.680319   17.612428       0.142883
# 8            0.994763   24.616762       0.555282
# ...               ...         ...            ...
# 99995        0.982545   31.479980       0.898402
# 99996        0.976469   20.090197       0.733135
# 99997        0.941688   25.256168       0.026844
# 99998        0.965836   36.755376       0.774259
# 99999        0.974298   17.374711       0.965819
#
# [57315 rows x 16 columns]

# %% [markdown]
# ### Scales of each samples
#
# |        |  Expected number of events per year | Generated number of events | Scale |
# |--------|-------------------------------------|----------------------------|-------|
# | Cosmics | 1.08e9 | 2.5e6 | 432 |
# | $\nu_e$-Ar CC signal | 116.5 | 1e5 | 116.5/1e5 |
# | $\nu_e$-Ar CC out fiducial | 813 | 4e5 | 813/4e5 |

# %%
fCosmic = 432.
fNueSignal = 116.5/1e5
fNueOutFiducial = 813./4e5
fNueSignal, fNueOutFiducial
# Out:
# (0.001165, 0.0020325)

# %%
cosmicCut = cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.FiducialEFrac>0.025)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.OutE>0.1)]
signalCut = signal[(signal.SignalVolEFrac>0.4)&(signal.FiducialEFrac>0.025)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.OutE>0.1)]
nueOutCut = nueOut[(nueOut.SignalVolEFrac>0.4)&(nueOut.FiducialEFrac>0.025)&(nueOut.MaxE>5.)&(nueOut.TotalE<52.)&(nueOut.OutE>0.1)]

# %%
SF = 100.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(cosmicCut.MaxE, weights = np.full_like(cosmicCut.MaxE, fCosmic), bins = np.linspace(0, 40, 41),
        histtype = 'step', lw = 2, label = 'Cosmic with no muon>5cm')
ax.hist(signalCut.MaxE, weights = np.full_like(signalCut.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41),
        histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC signal')
ax.hist(nueOutCut.MaxE, weights = np.full_like(nueOutCut.MaxE, fNueOutFiducial*SF), bins = np.linspace(0, 40, 41), 
        histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC outside')
ax.set_xlabel( r'Leading Energy [MeV]', fontsize = 16 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 16 )
ax.tick_params(axis = 'x', labelsize = 16)
ax.tick_params(axis = 'y', labelsize = 16)
ax.set_xlim([5, 40])
#ax.set_ylim( [0, 30000])
ax.legend( fontsize = 16)

ax.grid(":")

# %%
len(cosmicCut)
# Out:
# 82

# %%
cosmic[(cosmic.TopCRTE>0.)|(cosmic.BottomCRTE>0.)|(cosmic.FrontCRTE>0.)|(cosmic.BackCRTE>0.)|(cosmic.LeftCRTE>0.)|(cosmic.RightCRTE>0.)]
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE       MaxE  \
# 1        0    364   0.000000  0.000000  0.392915  0.392915  15.625915
# 2        0    390   0.000000  0.000000  0.148901  0.148901   0.126668
# 3        0    480   0.000000  0.000000  0.334323  0.334323  18.008526
# 4        0    796   0.073977  0.058413  0.000000  0.132390   0.073977
# 5        0    860   0.000000  0.000000  0.099884  0.099884   0.099884
# ...    ...    ...        ...       ...       ...       ...        ...
# 8538  2498    798   0.000000  0.984366  0.377349  1.361715   0.631195
# 8540  2498    899   0.000000  0.000000  0.053708  0.053708   0.053708
# 8541  2499    151   0.268691  0.039755  0.054821  0.363267   0.155253
# 8542  2499    184   0.000000  0.000000  0.216438  0.216438   0.119791
# 8543  2499    562   0.679984  0.000000  0.910751  1.590734   0.641247
#
#         TopCRTE  BottomCRTE  FrontCRTE   BackCRTE   LeftCRTE  RightCRTE  \
# 1     11.101328    0.000000   0.000000   0.000000  13.193037   0.341808
# 2      5.847214    8.366082   0.018158   0.581913   0.000000   0.000000
# 3      5.702259    5.616968   0.000000   0.000000   0.000000   0.000000
# 4      0.007804    0.000000   0.000000   0.000000   0.000000   2.125036
# 5      6.271216    6.378438   0.000000   0.857748   0.000000   0.000000
# ...         ...         ...        ...        ...        ...        ...
# 8538   0.000000    0.000000   0.000000  27.355723  15.919180   0.000000
# 8540   0.000000    0.000000   1.202076   0.000000   0.000000   0.000000
# 8541   0.000000    0.000000   0.000000   0.000000   0.000000   0.017279
# 8542   0.000000    0.000000   0.000000   9.305169   7.483774   0.000000
# 8543   6.513887    0.000000   0.000000   0.000000   0.000000   0.000000
#
#       SignalVolEFrac  SignalVolE  FiducialEFrac
# 1           0.000000    0.000000       0.000000
# 2           0.000000    0.000000       0.000000
# 3           0.000000    0.000000       0.000000
# 4           1.000000    0.132390       0.558784
# 5           0.000000    0.000000       0.000000
# ...              ...         ...            ...
# 8538        0.722887    0.984366       0.000000
# 8540        0.000000    0.000000       0.000000
# 8541        0.849090    0.308447       0.739652
# 8542        0.000000    0.000000       0.000000
# 8543        0.427465    0.679984       0.427465
#
# [6828 rows x 16 columns]

# %%
cosmic.TopCRTE.max(), cosmic.BottomCRTE.max(), cosmic.FrontCRTE.max(), cosmic.BackCRTE.max(), cosmic.LeftCRTE.max(), cosmic.RightCRTE.max()
# Out:
# (82.49340808244114,
#  203.46730753140844,
#  289.42573376600376,
#  1008.3384786017936,
#  250.2751017468555,
#  3108.829034811898)

# %%
signal[(signal.TopCRTE>0.)|(signal.BottomCRTE>0.)|(signal.FrontCRTE>0.)|(signal.BackCRTE>0.)|(signal.LeftCRTE>0.)|(signal.RightCRTE>0.)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0        0      0   0.000000   0.026611  18.707125  18.733736  15.237371
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 10       0     10   0.010894  34.610286   8.084882  42.706062  23.507860
# 12       0     12   1.143909  39.672094   1.454672  42.270675  28.521956
# 14       0     14   0.586053  27.087904   0.045622  27.719579  23.597800
# ...    ...    ...        ...        ...        ...        ...        ...
# 99989    9   9989  19.765976   0.289785   0.618669  20.674429  17.418603
# 99992    9   9992   7.769625  11.877627  12.659921  32.307172  27.431598
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#         TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  RightCRTE  \
# 0      0.000000    0.000000   0.170640  0.000000  0.000000   0.288692
# 3      0.000000    0.005238   0.000000  0.004326  0.000000   0.000000
# 10     0.000000    0.000000   0.000000  0.000000  0.058936   0.000000
# 12     0.078964    0.000000   0.000000  0.000000  0.000000   0.000000
# 14     0.000000    0.000000   0.000000  0.000000  0.232019   0.000000
# ...         ...         ...        ...       ...       ...        ...
# 99989  0.000000    0.084864   0.000000  0.000000  0.240789   0.000000
# 99992  0.000000    0.000000   0.000000  0.000000  0.216049   0.000000
# 99996  0.000000    0.454136   0.000000  0.000000  0.148523   0.000000
# 99997  0.000000    0.000000   1.777848  0.000000  0.000000   0.000000
# 99999  0.000000    0.000000   0.000000  0.000000  0.000000   0.233162
#
#        SignalVolEFrac  SignalVolE  FiducialEFrac
# 0            0.001420    0.026611       0.000000
# 3            0.990078   29.296249       0.868417
# 10           0.810685   34.621180       0.000255
# 12           0.965587   40.816003       0.027062
# 14           0.998354   27.673957       0.021142
# ...               ...         ...            ...
# 99989        0.970076   20.055761       0.956059
# 99992        0.608139   19.647251       0.240492
# 99996        0.976469   20.090197       0.733135
# 99997        0.941688   25.256168       0.026844
# 99999        0.974298   17.374711       0.965819
#
# [49152 rows x 16 columns]

# %%
signal.TopCRTE.max(), signal.BottomCRTE.max(), signal.FrontCRTE.max(), signal.BackCRTE.max(), signal.LeftCRTE.max(), signal.RightCRTE.max()
# Out:
# (15.247456726058076,
#  14.53751104680432,
#  20.78574716606716,
#  19.50716254032283,
#  17.181307500229565,
#  15.939971900520064)

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 3))

ax[0].hist( signal.TopCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Top')
ax[0].hist( signal.BottomCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Bottom')
ax[0].hist( signal.FrontCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Front')
ax[0].hist( signal.BackCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Back')
ax[0].hist( signal.LeftCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Left')
ax[0].hist( signal.RightCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Right')

ax[0].set_xlim([0, 0.008])

ax[1].hist( cosmic.TopCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Top')
ax[1].hist( cosmic.BottomCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Bottom')
ax[1].hist( cosmic.FrontCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Front')
ax[1].hist( cosmic.BackCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Back')
ax[1].hist( cosmic.LeftCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Left')
ax[1].hist( cosmic.RightCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Right')

ax[1].set_xlim([0, 1])

# ax[1].hist( cosmic.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
# ax[2].hist( nueOut.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the CRT')
    # iax.set_xlim([0, 0.008])
    iax.grid(':')
    iax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
CRTEcut = 1.
cosmicCut = cosmic[(cosmic.TopCRTE<=CRTEcut)&(cosmic.BottomCRTE<=CRTEcut)&(cosmic.FrontCRTE<=CRTEcut)&(cosmic.BackCRTE<=CRTEcut)&(cosmic.LeftCRTE<=CRTEcut)&(cosmic.RightCRTE<=CRTEcut)&(cosmic.SignalVolEFrac>0.4)&(cosmic.TotalE>10.)&(cosmic.TotalE<52.)&(cosmic.OutE>0.1)]

# %%
signalCut = signal[(signal.TopCRTE<=CRTEcut)&(signal.BottomCRTE<=CRTEcut)&(signal.FrontCRTE<=CRTEcut)&(signal.BackCRTE<=CRTEcut)&(signal.LeftCRTE<=CRTEcut)&(signal.RightCRTE<=CRTEcut)&(signal.SignalVolEFrac>0.4)&(signal.TotalE>10.)&(signal.TotalE<52.)&(signal.OutE>0.1)]

# %%
nueOutCut = nueOut[(nueOut.TopCRTE<=CRTEcut)&(nueOut.BottomCRTE<=CRTEcut)&(nueOut.FrontCRTE<=CRTEcut)&(nueOut.BackCRTE<=CRTEcut)&(nueOut.LeftCRTE<=CRTEcut)&(nueOut.RightCRTE<=CRTEcut)&(nueOut.SignalVolEFrac>0.4)&(nueOut.TotalE>10.)&(nueOut.TotalE<52.)&(nueOut.OutE>0.1)]

# %%
SF = 10.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(cosmicCut.MaxE, weights = np.full_like(cosmicCut.MaxE, fCosmic), bins = np.linspace(0, 40, 41),
        histtype = 'step', lw = 2, label = 'Cosmic with no muon>5cm')
ax.hist(signalCut.MaxE, weights = np.full_like(signalCut.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41),
        histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC signal x10')
ax.hist(nueOutCut.MaxE, weights = np.full_like(nueOutCut.MaxE, fNueOutFiducial*SF), bins = np.linspace(0, 40, 41), 
        histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC outside x10')
ax.set_xlabel( r'Leading Energy [MeV]', fontsize = 16 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 16 )
ax.tick_params(axis = 'x', labelsize = 16)
ax.tick_params(axis = 'y', labelsize = 16)
ax.set_xlim([5, 40])
#ax.set_ylim( [0, 30000])
ax.legend( fontsize = 16)

ax.grid(":")
fig.savefig('LeadingEnergy.pdf')

# %%
len(cosmicCut)
# Out:
# 21

# %%
len(signalCut)
# Out:
# 67907

# %%
len(nueOutCut)
# Out:
# 13079

# %%
21* fCosmic, 21*fCosmic/30, 67907*fNueSignal
# Out:
# (9072.0, 302.4, 79.111655)

# %%
np.sqrt(302.4)
# Out:
# 17.389652095427326

# %%
CRTEcut = 1.
cosmicCut = cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.TotalE>10.)&(cosmic.TotalE<52.)&(cosmic.OutE>0.1)]

# %%
len(cosmicCut)
# Out:
# 114

# %%
cosmicCut = cosmic[(cosmic.TopCRTE<=CRTEcut)&(cosmic.BottomCRTE<=CRTEcut)&(cosmic.FrontCRTE<=CRTEcut)&(cosmic.BackCRTE<=CRTEcut)&(cosmic.LeftCRTE<=CRTEcut)&(cosmic.RightCRTE<=CRTEcut)]

# %%
len(cosmicCut)
# Out:
# 3114
