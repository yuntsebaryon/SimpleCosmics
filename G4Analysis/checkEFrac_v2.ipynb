# %% [markdown]
# # Energy Deposition in LArTPC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cosmicFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/cosmicEFrac.csv'
signalFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/nueArCCSignalEFrac.csv'
nueOutFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/nueArCCoutEFrac.csv'
brnFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/brnEFrac.csv'
hogFile = '/Users/yuntse/data/coherent/preLArTPC/analysis/EFracv2/hogEFrac.csv'

# %%
cosmic = pd.read_csv( cosmicFile )
signal = pd.read_csv( signalFile )
nueOut = pd.read_csv( nueOutFile )
brn = pd.read_csv( brnFile )
hog = pd.read_csv( hogFile )

# %%
cosmic
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 0        0    251   0.000000  0.000000  0.084589  0.084589  0.069128
# 1        0    390   0.000000  0.000000  0.148901  0.148901  0.126668
# 2        0    796   0.073977  0.058413  0.000000  0.132390  0.073977
# 3        0    860   0.000000  0.000000  0.099884  0.099884  0.099884
# 4        1    354   0.000000  0.269251  0.274666  0.543916  0.160570
# ...    ...    ...        ...       ...       ...       ...       ...
# 7776  2498    820   0.000000  0.000000  0.302879  0.302879  0.220526
# 7777  2498    899   0.000000  0.000000  0.053708  0.053708  0.053708
# 7778  2499    151   0.268691  0.039755  0.054821  0.363267  0.155253
# 7779  2499    184   0.000000  0.000000  0.216438  0.216438  0.119791
# 7780  2499    562   0.679984  0.000000  0.910751  1.590734  0.641247
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0        0      0   0.000000   0.026611  18.707125  18.733736  15.237371
# 1        0      1   0.000000   7.279029  11.526980  18.806009  15.743186
# 2        0      2   1.547156   6.588975  26.289853  34.425985  25.637749
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022   0.113112  40.811681  29.338700
# ...    ...    ...        ...        ...        ...        ...        ...
# 99995    9   9995  28.784116   2.695864   0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
brn
# Out:
#         Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 0         0      2   0.221828  1.646689  1.223620  3.092138  1.639740
# 1         0      4   0.171937  0.590898  0.601816  1.364651  0.387829
# 2         0      8   2.417726  0.000000  0.052198  2.469925  1.823932
# 3         0      9   0.000000  0.000000  0.113136  0.113136  0.068647
# 4         0     11   0.000000  0.000000  0.281518  0.281518  0.178020
# ...     ...    ...        ...       ...       ...       ...       ...
# 189865   49   9988   0.000000  0.191780  0.290824  0.482604  0.151219
# 189866   49   9990   0.000000  0.000000  0.000000  0.000000  0.000000
# 189867   49   9995   0.000000  0.000000  0.686547  0.686547  0.268897
# 189868   49   9998   0.000000  0.000000  0.000000  0.000000  0.000000
# 189869   49   9999   2.358236  1.266029  0.115354  3.739619  1.952994
#
#         MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  \
# ...

# %%
hog
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 0        0      2        0.0  0.140121  0.000000  0.140121  0.102625
# 1        0     13        0.0  0.140147  0.007784  0.147931  0.116709
# 2        0     14        0.0  0.032369  0.073161  0.105530  0.072736
# 3        0     18        0.0  0.000000  0.071008  0.071008  0.060796
# 4        0     22        0.0  0.000000  0.048263  0.048263  0.048263
# ...    ...    ...        ...       ...       ...       ...       ...
# 11077    9   4974        0.0  0.000000  0.089269  0.089269  0.061403
# 11078    9   4976        0.0  0.000000  0.092410  0.092410  0.070838
# 11079    9   4981        0.0  0.077542  0.094487  0.172029  0.077542
# 11080    9   4994        0.0  0.000000  0.139151  0.139151  0.069936
# 11081    9   4995        0.0  0.122691  0.000000  0.122691  0.072469
#
#        MaxELength  pMaxE   TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
cosmic['SignalVolE'] = cosmic.FiducialE + cosmic.PartConE
signal['SignalVolE'] = signal.FiducialE + signal.PartConE
nueOut['SignalVolE'] = nueOut.FiducialE + nueOut.PartConE
brn['SignalVolE'] = brn.FiducialE + brn.PartConE
hog['SignalVolE'] = hog.FiducialE + hog.PartConE

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( brn.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[3].hist( nueOut.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')
ax[4].hist( hog.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')



for iax in ax:
    iax.set_xlabel('Energy Deposited in the Signal Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
cosmic['SignalVolEFrac'] = cosmic.SignalVolE / cosmic.TotalE
cosmic
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 0        0    251   0.000000  0.000000  0.084589  0.084589  0.069128
# 1        0    390   0.000000  0.000000  0.148901  0.148901  0.126668
# 2        0    796   0.073977  0.058413  0.000000  0.132390  0.073977
# 3        0    860   0.000000  0.000000  0.099884  0.099884  0.099884
# 4        1    354   0.000000  0.269251  0.274666  0.543916  0.160570
# ...    ...    ...        ...       ...       ...       ...       ...
# 7776  2498    820   0.000000  0.000000  0.302879  0.302879  0.220526
# 7777  2498    899   0.000000  0.000000  0.053708  0.053708  0.053708
# 7778  2499    151   0.268691  0.039755  0.054821  0.363267  0.155253
# 7779  2499    184   0.000000  0.000000  0.216438  0.216438  0.119791
# 7780  2499    562   0.679984  0.000000  0.910751  1.590734  0.641247
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal['SignalVolEFrac'] = signal.SignalVolE / signal.TotalE
nueOut['SignalVolEFrac'] = nueOut.SignalVolE / nueOut.TotalE
brn['SignalVolEFrac'] = brn.SignalVolE / brn.TotalE
hog['SignalVolEFrac'] = hog.SignalVolE / hog.TotalE

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[2].hist( brn.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[3].hist( nueOut.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')
ax[4].hist( hog.SignalVolEFrac, bins = np.linspace(0, 1, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')


for iax in ax:
    iax.set_xlabel('Energy Fraction in the Signal Volume')
    iax.set_xlim([0, 1])
    iax.grid(':')
    iax.legend( loc = 'upper center')
ax[4].legend( loc = 'upper right' )

# %%
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist( signal.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC Signal' )
ax.hist( cosmic.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, color = 'tab:orange',
        label = 'Cosmic' )
ax.hist( brn.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:green',
        label = 'BRN')
ax.hist( nueOut.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:brown',
        label = r'$\nu_e$-Ar CC Outside' )
ax.hist( hog.SignalVolEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:olive',
        label = 'Hot-off Gas')


ax.set_xlabel( 'Deposited Energy Fraction', fontsize = 20)
ax.set_ylabel( 'Arbitray Unit', fontsize = 20)
ax.tick_params( axis = 'x', labelsize = 20)
ax.tick_params( axis = 'y', labelsize = 20)
ax.set_title( 'Deposited Energy Fraction in the Signal Volume', fontsize = 20 )

ax.set_xlim([ 0, 1 ])
ax.grid(':')
ax.legend(loc = 'upper center', fontsize = 20)

fig.savefig('SignalVolEFraction.pdf')

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.OutE>1)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE      MaxE  \
# 42      10    185   0.924879   1.311020  1.958516   4.194415  1.147575
# 71      19     83   0.000000  12.976906  1.685846  14.662752  6.968210
# 76      19    787   0.000000   4.522047  1.259058   5.781105  5.461302
# 99      27    216   0.152494   5.007660  1.737041   6.897194  4.188125
# 122     33    859   0.000000   2.000681  1.033563   3.034243  1.489910
# ...    ...    ...        ...        ...       ...        ...       ...
# 7705  2478     74   5.350345   2.315919  1.601035   9.267298  4.986290
# 7720  2483    695   0.574152   2.641302  3.755894   6.971348  3.547314
# 7724  2484    343   0.000000   1.739496  2.476967   4.216464  2.923778
# 7739  2488    752   0.810198   0.778797  1.447286   3.036282  0.683563
# 7760  2496    109   3.379363   0.104562  1.956697   5.440622  2.114657
#
#       MaxELength  pMaxE   TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.OutE>1)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 6        0      6   0.844765  31.629057   1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413   8.276063  25.888491  17.328523
# 10       0     10   0.010894  34.610286   8.084882  42.706062  23.507860
# 12       0     12   1.143909  39.672094   1.454672  42.270675  28.521956
# 13       0     13   1.771562  34.814713   5.994312  42.580586  16.858767
# ...    ...    ...        ...        ...        ...        ...        ...
# 99987    9   9987  33.439328   2.377019   1.369508  37.185855  18.064338
# 99988    9   9988   0.467621  25.133688   3.643370  29.244679  25.985487
# 99992    9   9992   7.769625  11.877627  12.659921  32.307172  27.431598
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
#
#        MaxELength  pMaxE   TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.OutE>1)]
# Out:
#         Run  Event  FiducialE   PartConE       OutE      TotalE       MaxE  \
# 0         0      2   0.221828   1.646689   1.223620    3.092138   1.639740
# 23        0     50  20.092309   1.471451   2.980337   24.544097   7.951499
# 42        0     99   2.308692   6.431774   4.607710   13.348176   4.253622
# 48        0    120   7.895637   1.620896   1.057328   10.573861   7.025010
# 51        0    132   1.900997  21.805518  11.298026   35.004542  14.446106
# ...     ...    ...        ...        ...        ...         ...        ...
# 189842   49   9921   0.428276   0.446999   1.163548    2.038822   1.105295
# 189846   49   9930   0.000000  14.083196   2.073131   16.156327   6.433143
# 189848   49   9935   0.990969   1.421770   3.454676    5.867415   2.823715
# 189854   49   9960   0.000000   2.941027   1.093819    4.034846   2.341074
# 189857   49   9964   0.938362  55.813374  53.584650  110.336386  99.454205
#
# ...

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOut.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')
ax[2].hist( brn.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = 'BRN')
ax[4].hist( hog.OutE, bins = np.linspace(0, 10, 21), histtype = 'step', lw = 2, label = 'Hot-off Gas')


for iax in ax:
    iax.set_xlabel('Energy Deposited outside the Signal Volume')
    iax.set_xlim([0, 10])
    iax.grid(':')
    iax.legend()

# %%
brn.TotalE.max()
# Out:
# 342.3815133745607

# %%
brn[brn.TotalE>10]
# Out:
#         Run  Event  FiducialE    PartConE       OutE      TotalE        MaxE  \
# 12        0     29  50.092096    0.013937   0.236242   50.342275   49.985182
# 23        0     50  20.092309    1.471451   2.980337   24.544097    7.951499
# 42        0     99   2.308692    6.431774   4.607710   13.348176    4.253622
# 48        0    120   7.895637    1.620896   1.057328   10.573861    7.025010
# 51        0    132   1.900997   21.805518  11.298026   35.004542   14.446106
# ...     ...    ...        ...         ...        ...         ...         ...
# 189840   49   9919  30.825535    0.000000   0.168940   30.994475   30.400441
# 189841   49   9920   0.510985  155.927796  50.504610  206.943391  212.355940
# 189846   49   9930   0.000000   14.083196   2.073131   16.156327    6.433143
# 189857   49   9964   0.938362   55.813374  53.584650  110.336386   99.454205
# 189859   49   9969   0.000000   16.480613   0.474628   16.955241   16.128206
#
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (8, 3))

ax[0].hist( brn.MaxE, bins = np.linspace(0, 0.5, 11), histtype = 'step', lw = 2, label = 'BRN Total E')
ax[1].hist( brn.TotalE, bins = np.linspace(0, 0.5, 11), histtype = 'step', lw = 2, label = 'BRN Max E')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the TPC')
    iax.set_xlim([0, 0.5])
    iax.grid(':')
    iax.legend()

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOut.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')
ax[2].hist( brn.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[4].hist( hog.SignalVolE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the Signal Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( cosmic.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOut.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')
ax[2].hist( brn.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[4].hist( hog.TotalE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the TPC Volume')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.legend()

# %%
len(signal[signal.SignalVolEFrac>0.4]), len(cosmic[cosmic.SignalVolEFrac>0.4]), len(brn[brn.SignalVolEFrac>0.4])
# Out:
# (87658, 2724, 65840)

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.SignalVolE>5)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057  1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.SignalVolE>5)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 45      11    123   7.978759   0.145265   0.134800   8.258825   5.212990
# 71      19     83   0.000000  12.976906   1.685846  14.662752   6.968210
# 99      27    216   0.152494   5.007660   1.737041   6.897194   4.188125
# 135     39    162   4.541694   0.551072   7.412122  12.504888   3.895339
# 179     53    109   4.911922   0.544437   0.000000   5.456359   3.854567
# ...    ...    ...        ...        ...        ...        ...        ...
# 7484  2415    853  14.217589   7.339909  28.411064  49.968563  12.338942
# 7536  2426    648   5.401424  24.240384   4.497352  34.139160  12.042656
# 7569  2436    426  10.592042   0.323491   2.144363  13.059896   5.799050
# 7672  2468     18   0.000000  18.229334   0.839664  19.068998  16.213245
# 7705  2478     74   5.350345   2.315919   1.601035   9.267298   4.986290
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.SignalVolE>5)]
# Out:
#         Run  Event  FiducialE    PartConE       OutE      TotalE        MaxE  \
# 12        0     29  50.092096    0.013937   0.236242   50.342275   49.985182
# 14        0     32   0.000000    5.138167   0.178835    5.317002    3.137829
# 19        0     43   8.048061    0.000000   0.000000    8.048061    7.486599
# 23        0     50  20.092309    1.471451   2.980337   24.544097    7.951499
# 32        0     75   0.234805    5.856005   0.437828    6.528638    4.351217
# ...     ...    ...        ...         ...        ...         ...         ...
# 189840   49   9919  30.825535    0.000000   0.168940   30.994475   30.400441
# 189841   49   9920   0.510985  155.927796  50.504610  206.943391  212.355940
# 189846   49   9930   0.000000   14.083196   2.073131   16.156327    6.433143
# 189857   49   9964   0.938362   55.813374  53.584650  110.336386   99.454205
# 189859   49   9969   0.000000   16.480613   0.474628   16.955241   16.128206
#
# ...

# %%
cosmic['FiducialEFrac'] = cosmic.FiducialE / cosmic.TotalE
signal['FiducialEFrac'] = signal.FiducialE / signal.TotalE
nueOut['FiducialEFrac'] = nueOut.FiducialE / nueOut.TotalE
brn['FiducialEFrac'] = brn.FiducialE / brn.TotalE
hog['FiducialEFrac'] = hog.FiducialE / hog.TotalE

# %%
fig, ax = plt.subplots( figsize = (8, 6) )

ax.hist( signal.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC Signal' )
ax.hist( cosmic.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, color = 'tab:orange',
        label = 'Cosmic' )
ax.hist( brn.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:green',
        label = 'BRN' )
ax.hist( nueOut.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:brown',
        label = r'$\nu_e$-Ar CC Outside' )
ax.hist( hog.FiducialEFrac, bins = np.linspace(0, 1, 41), density = True, histtype = 'step', lw = 2, linestyle = '-.', color = 'tab:olive',
        label = 'Hot-off Gas' )

ax.set_xlabel( 'Deposited Energy Fraction in the Fiducial Volume', fontsize = 16)
ax.set_ylabel( 'Arbitray Unit', fontsize = 16)
ax.tick_params( axis = 'x', labelsize = 16)
ax.tick_params( axis = 'y', labelsize = 16)

ax.set_xlim([ 0, 1 ])
ax.grid(':')
ax.legend(fontsize = 16)

# %%
cosmic[cosmic.FiducialEFrac>0.025]
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 2        0    796   0.073977  0.058413  0.000000  0.132390  0.073977
# 5        1    389   0.065921  0.113706  0.000000  0.179627  0.081084
# 6        1    505   0.406363  0.130759  0.321590  0.858713  0.360997
# 8        2     87   1.993693  1.132214  0.000000  3.125907  0.880995
# 24       6     21   0.497373  0.000000  0.106635  0.604007  0.216696
# ...    ...    ...        ...       ...       ...       ...       ...
# 7760  2496    109   3.379363  0.104562  1.956697  5.440622  2.114657
# 7768  2497    555   0.857987  0.942332  0.296239  2.096557  0.855674
# 7774  2498    718   1.961833  0.000000  0.100173  2.062006  1.936890
# 7778  2499    151   0.268691  0.039755  0.054821  0.363267  0.155253
# 7780  2499    562   0.679984  0.000000  0.910751  1.590734  0.641247
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
signal[signal.FiducialEFrac>0.025]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 2        0      2   1.547156   6.588975  26.289853  34.425985  25.637749
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022   0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787   0.358493  38.358345  27.304520
# 7        0      7   3.699015  13.913413   8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...        ...        ...        ...
# 99995    9   9995  28.784116   2.695864   0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
nueOut[nueOut.FiducialEFrac>0.025]
# Out:
#         Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0         0      0   2.052607  10.040593  18.964540  31.057740  20.380514
# 1         0      1   0.424514   0.139770   0.202373   0.766656   0.157639
# 2         0      3   0.244532   0.220029   1.145129   1.609690   0.942383
# 3         0      4  18.804507  11.480983  14.173285  44.458775  16.678509
# 6         0      9   2.949516   0.475579   0.469707   3.894803   2.179923
# ...     ...    ...        ...        ...        ...        ...        ...
# 233509   39   9982   0.459121   0.249363   0.291606   1.000090   0.459121
# 233510   39   9983   1.864387   1.586496  18.264758  21.715641  11.815670
# 233511   39   9987   0.107435   0.953809   0.652256   1.713500   0.889359
# 233514   39   9991   0.083812   0.009544   1.999922   2.093278   1.555416
# 233516   39   9993   0.460785   0.405848   0.653404   1.520037   0.528793
#
#         MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
brn[brn.FiducialEFrac>0.025]
# Out:
#         Run  Event  FiducialE  PartConE      OutE     TotalE       MaxE  \
# 0         0      2   0.221828  1.646689  1.223620   3.092138   1.639740
# 1         0      4   0.171937  0.590898  0.601816   1.364651   0.387829
# 2         0      8   2.417726  0.000000  0.052198   2.469925   1.823932
# 5         0     12   3.026259  0.246004  0.000000   3.272263   2.626061
# 12        0     29  50.092096  0.013937  0.236242  50.342275  49.985182
# ...     ...    ...        ...       ...       ...        ...        ...
# 189842   49   9921   0.428276  0.446999  1.163548   2.038822   1.105295
# 189845   49   9929   0.303314  0.255535  0.008240   0.567088   0.145381
# 189848   49   9935   0.990969  1.421770  3.454676   5.867415   2.823715
# 189862   49   9980   1.377595  3.184945  0.161518   4.724058   2.820290
# 189869   49   9999   2.358236  1.266029  0.115354   3.739619   1.952994
#
#         MaxELength      pMaxE    TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  \
# ...

# %%
# pd.set_option('display.max_rows', 20)
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 71      19     83   0.000000  12.976906   1.685846  14.662752   6.968210
# 186     54     31  10.160078  13.543609  24.842258  48.545946  11.464938
# 195     56    506   3.267359  24.038239  16.248782  43.554381  13.749409
# 254     73    913   0.163904  12.360827   9.872494  22.397224   5.059116
# 266     75    761   0.000000  12.843174   0.856558  13.699732   7.390607
# ...    ...    ...        ...        ...        ...        ...        ...
# 7454  2406    768   4.313120  13.980253   1.229486  19.522859  10.042583
# 7484  2415    853  14.217589   7.339909  28.411064  49.968563  12.338942
# 7536  2426    648   5.401424  24.240384   4.497352  34.139160  12.042656
# 7569  2436    426  10.592042   0.323491   2.144363  13.059896   5.799050
# 7672  2468     18   0.000000  18.229334   0.839664  19.068998  16.213245
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE    BackCRTE  \
# ...

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.SignalVolE>5)&(signal.TotalE>10)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057  1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)]
# Out:
#         Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 12        0     29  50.092096   0.013937   0.236242  50.342275  49.985182
# 23        0     50  20.092309   1.471451   2.980337  24.544097   7.951499
# 48        0    120   7.895637   1.620896   1.057328  10.573861   7.025010
# 51        0    132   1.900997  21.805518  11.298026  35.004542  14.446106
# 71        0    179   0.405855  17.447520   0.531646  18.385021  13.420689
# ...     ...    ...        ...        ...        ...        ...        ...
# 189751   49   9686   0.000000   9.192143   2.246237  11.438380   5.193098
# 189775   49   9742  32.667654   1.177834   0.541384  34.386872  18.934225
# 189840   49   9919  30.825535   0.000000   0.168940  30.994475  30.400441
# 189846   49   9930   0.000000  14.083196   2.073131  16.156327   6.433143
# 189859   49   9969   0.000000  16.480613   0.474628  16.955241  16.128206
#
#         MaxELength      pMaxE   TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.pMaxE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( brn.pMaxE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[2].hist( cosmic.pMaxE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOut.pMaxE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Out')
ax[4].hist( hog.pMaxE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-Off Gas')


for iax in ax:
    iax.set_xlabel('Leading Proton Energy [MeV]')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.semilogy()
    iax.legend()

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signal.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( brn.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[2].hist( cosmic.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Out')
ax[4].hist( hog.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')


for iax in ax:
    iax.set_xlabel('Leading Charged Particle Length [mm]')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.semilogy()
    iax.legend()

# %%
signal[(signal.SignalVolEFrac>0.4)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.SignalVolE>5)&(signal.TotalE>10)&(signal.pMaxE<35)]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057  1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal[signal.pMaxE>12.]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 31181    3   1181  27.677127   0.139429  0.000000  27.816556  16.981417
# 41567    4   1567   2.785773  33.118893  0.069090  35.973757  14.147160
# 42468    4   2468   0.015839  24.240081  0.000000  24.255920  13.050471
# 52775    5   2775   0.000000  15.645391  8.685631  24.331022  13.061499
# 59370    5   9370   4.911882  21.753523  0.336554  27.001959  12.051956
# 78813    7   8813  28.851349   0.415188  0.149516  29.416053  12.949187
# 85683    8   5683  27.209004   0.194127  4.438914  31.842045  12.879662
# 97678    9   7678   0.678640  28.085619  0.676154  29.440413  12.184365
#
#        MaxELength      pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  \
# 31181    3.435600  16.981417      0.0         0.0   0.000000       0.0
# 41567    2.477806  14.147160      0.0         0.0   0.000000       0.0
# 42468    2.203671  13.050471      0.0         0.0   0.000000       0.0
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<20)]
# Out:
#         Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 23        0     50  20.092309   1.471451   2.980337  24.544097   7.951499
# 48        0    120   7.895637   1.620896   1.057328  10.573861   7.025010
# 51        0    132   1.900997  21.805518  11.298026  35.004542  14.446106
# 71        0    179   0.405855  17.447520   0.531646  18.385021  13.420689
# 77        0    200   1.109068  12.266065   0.008931  13.384064  11.943758
# ...     ...    ...        ...        ...        ...        ...        ...
# 189738   49   9659  32.080747   1.943051   1.870280  35.894077  10.438857
# 189751   49   9686   0.000000   9.192143   2.246237  11.438380   5.193098
# 189775   49   9742  32.667654   1.177834   0.541384  34.386872  18.934225
# 189846   49   9930   0.000000  14.083196   2.073131  16.156327   6.433143
# 189859   49   9969   0.000000  16.480613   0.474628  16.955241  16.128206
#
#         MaxELength      pMaxE   TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<12)]
# Out:
#         Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 23        0     50  20.092309   1.471451  2.980337  24.544097   7.951499
# 48        0    120   7.895637   1.620896  1.057328  10.573861   7.025010
# 77        0    200   1.109068  12.266065  0.008931  13.384064  11.943758
# 155       0    413   1.935324   6.994923  8.118102  17.048349   6.207593
# 162       0    429   1.212118   7.685390  5.139558  14.037067   6.070917
# ...     ...    ...        ...        ...       ...        ...        ...
# 189607   49   9326  25.936578   2.547324  3.333683  31.817585  11.465698
# 189698   49   9564   8.693273   6.150535  9.190172  24.033979   5.813497
# 189738   49   9659  32.080747   1.943051  1.870280  35.894077  10.438857
# 189751   49   9686   0.000000   9.192143  2.246237  11.438380   5.193098
# 189846   49   9930   0.000000  14.083196  2.073131  16.156327   6.433143
#
#         MaxELength      pMaxE   TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<35)]
# Out:
#         Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 23        0     50  20.092309   1.471451   2.980337  24.544097   7.951499
# 48        0    120   7.895637   1.620896   1.057328  10.573861   7.025010
# 51        0    132   1.900997  21.805518  11.298026  35.004542  14.446106
# 71        0    179   0.405855  17.447520   0.531646  18.385021  13.420689
# 77        0    200   1.109068  12.266065   0.008931  13.384064  11.943758
# ...     ...    ...        ...        ...        ...        ...        ...
# 189751   49   9686   0.000000   9.192143   2.246237  11.438380   5.193098
# 189775   49   9742  32.667654   1.177834   0.541384  34.386872  18.934225
# 189840   49   9919  30.825535   0.000000   0.168940  30.994475  30.400441
# 189846   49   9930   0.000000  14.083196   2.073131  16.156327   6.433143
# 189859   49   9969   0.000000  16.480613   0.474628  16.955241  16.128206
#
#         MaxELength      pMaxE   TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)&(cosmic.pMaxE<12)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 71      19     83   0.000000  12.976906   1.685846  14.662752   6.968210
# 186     54     31  10.160078  13.543609  24.842258  48.545946  11.464938
# 195     56    506   3.267359  24.038239  16.248782  43.554381  13.749409
# 254     73    913   0.163904  12.360827   9.872494  22.397224   5.059116
# 266     75    761   0.000000  12.843174   0.856558  13.699732   7.390607
# ...    ...    ...        ...        ...        ...        ...        ...
# 7454  2406    768   4.313120  13.980253   1.229486  19.522859  10.042583
# 7484  2415    853  14.217589   7.339909  28.411064  49.968563  12.338942
# 7536  2426    648   5.401424  24.240384   4.497352  34.139160  12.042656
# 7569  2436    426  10.592042   0.323491   2.144363  13.059896   5.799050
# 7672  2468     18   0.000000  18.229334   0.839664  19.068998  16.213245
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE    BackCRTE  \
# ...

# %%
cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)&(cosmic.pMaxE<35)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 71      19     83   0.000000  12.976906   1.685846  14.662752   6.968210
# 186     54     31  10.160078  13.543609  24.842258  48.545946  11.464938
# 195     56    506   3.267359  24.038239  16.248782  43.554381  13.749409
# 254     73    913   0.163904  12.360827   9.872494  22.397224   5.059116
# 266     75    761   0.000000  12.843174   0.856558  13.699732   7.390607
# ...    ...    ...        ...        ...        ...        ...        ...
# 7454  2406    768   4.313120  13.980253   1.229486  19.522859  10.042583
# 7484  2415    853  14.217589   7.339909  28.411064  49.968563  12.338942
# 7536  2426    648   5.401424  24.240384   4.497352  34.139160  12.042656
# 7569  2436    426  10.592042   0.323491   2.144363  13.059896   5.799050
# 7672  2468     18   0.000000  18.229334   0.839664  19.068998  16.213245
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE    BackCRTE  \
# ...

# %% [markdown]
# ### Scales of each samples
#
# |        |  Expected number of events per year | Generated number of events | Scale |
# |--------|-------------------------------------|----------------------------|-------|
# | $\nu_e$-Ar CC signal | 116.5 | 1e5 | 116.5/1e5 |
# | Cosmics | 1.08e9 | 2.5e6 | 432 |
# | BRN | 1.56e5 | 5e5 | 0.312 |
# | $\nu_e$-Ar CC out fiducial | 813 | 4e5 | 813/4e5 |
# | Hot-off Gas | 2.592e10 | 50000 | 518400 |

# %%
fCosmic = 432.
fNueSignal = 116.5/1e5
fNueOutFiducial = 813./4e5
fBRN = 1.56/5.
fHOG = 518400.
fNueSignal, fNueOutFiducial, fBRN, fHOG
# Out:
# (0.001165, 0.0020325, 0.312, 518400.0)

# %%
SF = 1.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(signal.MaxE, weights = np.full_like(signal.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41), color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC signal')
ax.hist(cosmic.MaxE, weights = np.full_like(cosmic.MaxE, fCosmic), bins = np.linspace(0, 40, 41), color = 'tab:orange',
        histtype = 'step', lw = 2, label = 'Cosmics')
ax.hist(brn.MaxE, weights = np.full_like(brn.MaxE, fBRN), bins = np.linspace(0, 40, 41), color = 'tab:green',
        histtype = 'step', linestyle = '-.', lw = 2, label = 'BRN')
ax.hist(nueOut.MaxE, weights = np.full_like(nueOut.MaxE, fNueOutFiducial), bins = np.linspace(0, 40, 41), color = 'tab:brown',
        histtype = 'step', linestyle = '-.', lw = 2, label = r'$\nu_e$-Ar CC outside')
ax.hist(hog.MaxE, weights = np.full_like(hog.MaxE, fHOG), bins = np.linspace(0, 40, 41), color = 'khaki',
        label = 'Hot-off Gas')

ax.set_xlabel( r'Deposited Energy of the Leading Charged Cluster [MeV]', fontsize = 16 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 20 )
ax.tick_params(axis = 'x', labelsize = 20)
ax.tick_params(axis = 'y', labelsize = 20)
ax.set_xlim([0, 40])
ax.set_ylim( [0, 30000])
ax.legend( fontsize = 20)
ax.set_title('Muon Length<5cm', fontsize = 20)

ax.grid(":")
fig.savefig('NoCut.pdf')

# %%
SF = 1000.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(signal.TotalE, weights = np.full_like(signal.TotalE, fNueSignal*SF), bins = np.linspace(0, 60, 61), color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC signal x1000')
ax.hist(cosmic.TotalE, weights = np.full_like(cosmic.TotalE, fCosmic), bins = np.linspace(0, 60, 61), color = 'tab:orange',
        histtype = 'step', lw = 2, label = 'Cosmics')
ax.hist(brn.TotalE, weights = np.full_like(brn.TotalE, fBRN), bins = np.linspace(0, 60, 61), color = 'tab:green',
        histtype = 'step', linestyle = '-.', lw = 2, label = 'BRN')
ax.hist(nueOut.TotalE, weights = np.full_like(nueOut.TotalE, fNueOutFiducial), bins = np.linspace(0, 60, 61), color = 'tab:brown',
        histtype = 'step', linestyle = '-.', lw = 2, label = r'$\nu_e$-Ar CC outside')
ax.hist(hog.TotalE, weights = np.full_like(hog.TotalE, fHOG), bins = np.linspace(0, 60, 61), color = 'khaki',
        label = 'Hot-off Gas')

ax.set_xlabel( r'Total Deposited Energy [MeV]', fontsize = 20 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 20 )
ax.tick_params(axis = 'x', labelsize = 20)
ax.tick_params(axis = 'y', labelsize = 20)
ax.set_xlim([0, 60])
ax.set_ylim( [0, 100000])
ax.legend( fontsize = 20)
ax.set_title('Muon Length<5cm', fontsize = 20)

ax.grid(":")
fig.savefig('NoCutTotalEx1000.pdf')

# %%
cosmicCut = cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)&(cosmic.pMaxE<35)]
signalCut = signal[(signal.SignalVolEFrac>0.4)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.SignalVolE>5)&(signal.TotalE>10)&(signal.pMaxE<35)]
nueOutCut = nueOut[(nueOut.SignalVolEFrac>0.4)&(nueOut.MaxE>5.)&(nueOut.TotalE>52.)&(nueOut.SignalVolE>5)&(nueOut.TotalE>10)&(nueOut.pMaxE<35)]
brnCut = brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<35)]
hogCut = hog[(hog.SignalVolEFrac>0.4)&(hog.MaxE>5.)&(hog.TotalE<52.)&(hog.SignalVolE>5)&(hog.TotalE>10)&(hog.pMaxE<35)]

# %%
hogCut
# Out:
# Empty DataFrame
# Columns: [Run, Event, FiducialE, PartConE, OutE, TotalE, MaxE, MaxELength, pMaxE, TopCRTE, BottomCRTE, FrontCRTE, BackCRTE, LeftCRTE, RightCRTE, SignalVolE, SignalVolEFrac, FiducialEFrac]
# Index: []

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 3))

ax[0].hist( signalCut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Signal')
ax[1].hist( brnCut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'BRN')
ax[2].hist( cosmicCut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
ax[3].hist( nueOutCut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Out')
ax[4].hist( hogCut.MaxELength, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Hot-off Gas')


for iax in ax:
    iax.set_xlabel('Leading Charged Particle Length [mm]')
    iax.set_xlim([0, 40])
    iax.grid(':')
    iax.semilogy()
    iax.legend()
# Out:
# /var/folders/bn/24gl1c290ls54cq54cz7rt9sfm8jyc/T/ipykernel_29673/297164759.py:14: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   iax.semilogy()
# /Users/yuntse/opt/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   func(*args, **kwargs)

# %%
cosmicCut = cosmic[(cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)&(cosmic.pMaxE<35)&(cosmic.MaxELength>15)]
signalCut = signal[(signal.SignalVolEFrac>0.4)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.SignalVolE>5)&(signal.TotalE>10)&(signal.pMaxE<35)&(signal.MaxELength>15)]
nueOutCut = nueOut[(nueOut.SignalVolEFrac>0.4)&(nueOut.MaxE>5.)&(nueOut.TotalE>52.)&(nueOut.SignalVolE>5)&(nueOut.TotalE>10)&(nueOut.pMaxE<35)&(nueOut.MaxELength>15)]
brnCut = brn[(brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<35)&(brn.MaxELength>15)]
hogCut = hog[(hog.SignalVolEFrac>0.4)&(hog.MaxE>5.)&(hog.TotalE<52.)&(hog.SignalVolE>5)&(hog.TotalE>10)&(hog.pMaxE<35)&(hog.MaxELength>15)]

# %%
len(signalCut), len(cosmicCut), len(brnCut), len(hogCut)
# Out:
# (85819, 103, 653, 0)

# %%
SF = 100.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(signalCut.MaxE, weights = np.full_like(signalCut.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41), color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC signal x 100')
ax.hist(cosmicCut.MaxE, weights = np.full_like(cosmicCut.MaxE, fCosmic), bins = np.linspace(0, 40, 41), color = 'tab:orange',
        histtype = 'step', lw = 2, label = 'Cosmic with no muon>5cm')
ax.hist(brnCut.MaxE, weights = np.full_like(brnCut.MaxE, fBRN), bins = np.linspace(0, 40, 41), color = 'tab:green',
        histtype = 'step', linestyle = '-.', lw = 2, label = 'BRN')
ax.hist(nueOutCut.MaxE, weights = np.full_like(nueOutCut.MaxE, fNueOutFiducial), bins = np.linspace(0, 40, 41), color = 'tab:brown',
        histtype = 'step', linestyle = '-.', lw = 2, label = r'$\nu_e$-Ar CC outside')
ax.hist(hogCut.MaxE, weights = np.full_like(hogCut.MaxE, fHOG), bins = np.linspace(0, 40, 41), color = 'khaki',
        label = 'Hot-off Gas')
ax.set_xlabel( r'Leading Charged Particle Deposited Energy [MeV]', fontsize = 20 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 20 )
ax.tick_params(axis = 'x', labelsize = 20)
ax.tick_params(axis = 'y', labelsize = 20)
ax.set_xlim([5, 40])
#ax.set_ylim( [0, 30000])
ax.legend( fontsize = 18)
ax.set_title('TPC Selection', fontsize = 20)

ax.grid(":")
fig.savefig('TPCCutsx100.pdf')

# %%
len(cosmicCut)
# Out:
# 103

# %%
cosmic[(cosmic.TopCRTE>0.)|(cosmic.BottomCRTE>0.)|(cosmic.FrontCRTE>0.)|(cosmic.BackCRTE>0.)|(cosmic.LeftCRTE>0.)|(cosmic.RightCRTE>0.)]
# Out:
#        Run  Event  FiducialE  PartConE      OutE    TotalE      MaxE  \
# 1        0    390   0.000000  0.000000  0.148901  0.148901  0.126668
# 2        0    796   0.073977  0.058413  0.000000  0.132390  0.073977
# 3        0    860   0.000000  0.000000  0.099884  0.099884  0.099884
# 4        1    354   0.000000  0.269251  0.274666  0.543916  0.160570
# 5        1    389   0.065921  0.113706  0.000000  0.179627  0.081084
# ...    ...    ...        ...       ...       ...       ...       ...
# 7775  2498    798   0.000000  0.984366  0.377349  1.361715  0.631195
# 7777  2498    899   0.000000  0.000000  0.053708  0.053708  0.053708
# 7778  2499    151   0.268691  0.039755  0.054821  0.363267  0.155253
# 7779  2499    184   0.000000  0.000000  0.216438  0.216438  0.119791
# 7780  2499    562   0.679984  0.000000  0.910751  1.590734  0.641247
#
#       MaxELength  pMaxE    TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
cosmic.TopCRTE.max(), cosmic.BottomCRTE.max(), cosmic.FrontCRTE.max(), cosmic.BackCRTE.max(), cosmic.LeftCRTE.max(), cosmic.RightCRTE.max()
# Out:
# (82.49340808244114,
#  203.46730753140844,
#  289.42573376600376,
#  1008.3384786017936,
#  250.2751017468555,
#  3108.829034811898)

# %%
signal[(signal.TopCRTE>0.)|(signal.BottomCRTE>0.)|(signal.FrontCRTE>0.)|(signal.BackCRTE>0.)|(signal.LeftCRTE>0.)|(signal.RightCRTE>0.)]
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 0        0      0   0.000000   0.026611  18.707125  18.733736  15.237371
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 10       0     10   0.010894  34.610286   8.084882  42.706062  23.507860
# 12       0     12   1.143909  39.672094   1.454672  42.270675  28.521956
# 14       0     14   0.586053  27.087904   0.045622  27.719579  23.597800
# ...    ...    ...        ...        ...        ...        ...        ...
# 99989    9   9989  19.765976   0.289785   0.618669  20.674429  17.418603
# 99992    9   9992   7.769625  11.877627  12.659921  32.307172  27.431598
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220   1.563942  26.820110  17.916317
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE   TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal.TopCRTE.max(), signal.BottomCRTE.max(), signal.FrontCRTE.max(), signal.BackCRTE.max(), signal.LeftCRTE.max(), signal.RightCRTE.max()
# Out:
# (15.247456726058076,
#  14.53751104680432,
#  20.78574716606716,
#  19.50716254032283,
#  17.181307500229565,
#  15.939971900520064)

# %%
fig, ax = plt.subplots(1, 2, figsize = (8, 3))

ax[0].hist( signal.TopCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Top')
ax[0].hist( signal.BottomCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Bottom')
ax[0].hist( signal.FrontCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Front')
ax[0].hist( signal.BackCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Back')
ax[0].hist( signal.LeftCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Left')
ax[0].hist( signal.RightCRTE, bins = np.linspace(0, 0.008, 51), histtype = 'step', lw = 2, label = 'Right')

ax[0].set_xlim([0, 0.008])

ax[1].hist( cosmic.TopCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Top')
ax[1].hist( cosmic.BottomCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Bottom')
ax[1].hist( cosmic.FrontCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Front')
ax[1].hist( cosmic.BackCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Back')
ax[1].hist( cosmic.LeftCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Left')
ax[1].hist( cosmic.RightCRTE, bins = np.linspace(0, 1, 51), histtype = 'step', lw = 2, label = 'Right')

ax[1].set_xlim([0, 1])

# ax[1].hist( cosmic.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = 'Cosmic')
# ax[2].hist( nueOut.FiducialE, bins = np.linspace(0, 40, 41), histtype = 'step', lw = 2, label = r'$\nu_e$-Ar CC Outside')

for iax in ax:
    iax.set_xlabel('Energy Deposited in the CRT')
    # iax.set_xlim([0, 0.008])
    iax.grid(':')
    iax.legend()

# %%
CRTEcut = 1.
cosmicCRTMask = (cosmic.TopCRTE<=CRTEcut)&(cosmic.BottomCRTE<=CRTEcut)&(cosmic.FrontCRTE<=CRTEcut)&(cosmic.BackCRTE<=CRTEcut)& \
                (cosmic.LeftCRTE<=CRTEcut)&(cosmic.RightCRTE<=CRTEcut)
cosmicTPCMask = (cosmic.SignalVolEFrac>0.4)&(cosmic.MaxE>5.)&(cosmic.TotalE<52.)&(cosmic.SignalVolE>5)&(cosmic.TotalE>10)& \
                (cosmic.pMaxE<35)&(cosmic.MaxELength>15)
cosmicCut = cosmic[cosmicCRTMask&cosmicTPCMask]
len(cosmicCut), len(cosmic[cosmicTPCMask])
# Out:
# (26, 103)

# %%
signalCRTMask = (signal.TopCRTE<=CRTEcut)&(signal.BottomCRTE<=CRTEcut)&(signal.FrontCRTE<=CRTEcut)&(signal.BackCRTE<=CRTEcut)& \
                (signal.LeftCRTE<=CRTEcut)&(signal.RightCRTE<=CRTEcut)
signalTPCMask = (signal.SignalVolEFrac>0.4)&(signal.MaxE>5.)&(signal.TotalE<52.)&(signal.SignalVolE>5)&(signal.TotalE>10)& \
                (signal.pMaxE<35)&(signal.MaxELength>15)
signalCut = signal[signalCRTMask&signalTPCMask]
signalCut
# Out:
#        Run  Event  FiducialE   PartConE       OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936   0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022   0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787   0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057   1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413   8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...        ...        ...        ...
# 99992    9   9992   7.769625  11.877627  12.659921  32.307172  27.431598
# 99995    9   9995  28.784116   2.695864   0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426   0.484132  20.574330   9.045617
# 99998    9   9998  29.464848   7.290528   1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211   0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
signal[signalTPCMask]
# Out:
#        Run  Event  FiducialE   PartConE      OutE     TotalE       MaxE  \
# 3        0      3  25.696313   3.599936  0.293578  29.589827  20.508206
# 4        0      4  39.875547   0.823022  0.113112  40.811681  29.338700
# 5        0      5  37.763065   0.236787  0.358493  38.358345  27.304520
# 6        0      6   0.844765  31.629057  1.459494  33.933316  23.034244
# 7        0      7   3.699015  13.913413  8.276063  25.888491  17.328523
# ...    ...    ...        ...        ...       ...        ...        ...
# 99995    9   9995  28.784116   2.695864  0.559245  32.039225  18.381587
# 99996    9   9996  15.083771   5.006426  0.484132  20.574330   9.045617
# 99997    9   9997   0.719947  24.536220  1.563942  26.820110  17.916317
# 99998    9   9998  29.464848   7.290528  1.300145  38.055521  23.173106
# 99999    9   9999  17.223500   0.151211  0.458346  17.833057  11.504074
#
#        MaxELength  pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  LeftCRTE  \
# ...

# %%
brnCRTMask = (brn.TopCRTE<=CRTEcut)&(brn.BottomCRTE<=CRTEcut)&(brn.FrontCRTE<=CRTEcut)&(brn.BackCRTE<=CRTEcut)& \
             (brn.LeftCRTE<=CRTEcut)&(brn.RightCRTE<=CRTEcut)
brnTPCMask = (brn.SignalVolEFrac>0.4)&(brn.MaxE>5.)&(brn.TotalE<52.)&(brn.SignalVolE>5)&(brn.TotalE>10)&(brn.pMaxE<35)& \
             (brn.MaxELength>15)
brnCut = brn[brnCRTMask&brnTPCMask]
brnCut
# Out:
#         Run  Event  FiducialE   PartConE      OutE     TotalE      MaxE  \
# 804       0   2190   8.647251  10.390071  1.269104  20.306427  5.102645
# 891       0   2414   5.031535   6.889422  0.226757  12.147715  6.238098
# 1219      0   3227   0.000000   6.768631  3.501949  10.270580  5.081177
# 2601      0   6768   0.476542   6.106542  3.973582  10.556666  5.385354
# 3231      0   8414  11.838980   1.355356  1.811697  15.006033  6.505563
# ...     ...    ...        ...        ...       ...        ...       ...
# 187586   49   3896   9.336192   0.455352  0.620304  10.411848  5.522237
# 187727   49   4258   6.193572   1.503626  5.997198  13.694396  5.094698
# 188369   49   5991   5.090615   0.675442  5.828308  11.594364  6.401130
# 188590   49   6517   5.438321   4.867237  0.043567  10.349126  5.102988
# 189590   49   9290   8.732355   1.129431  0.201518  10.063305  7.661287
#
#         MaxELength     pMaxE  TopCRTE  BottomCRTE  FrontCRTE  BackCRTE  \
# ...

# %%
brn[brnTPCMask]
# Out:
#         Run  Event  FiducialE   PartConE      OutE     TotalE      MaxE  \
# 48        0    120   7.895637   1.620896  1.057328  10.573861  7.025010
# 162       0    429   1.212118   7.685390  5.139558  14.037067  6.070917
# 332       0    898   4.804288   7.270937  1.139821  13.215046  5.223739
# 804       0   2190   8.647251  10.390071  1.269104  20.306427  5.102645
# 891       0   2414   5.031535   6.889422  0.226757  12.147715  6.238098
# ...     ...    ...        ...        ...       ...        ...       ...
# 188624   49   6627  14.954093   5.201843  2.190861  22.346797  5.369505
# 189122   49   8046   8.268834   1.672500  7.167498  17.108832  5.405458
# 189476   49   8973   2.120592  11.570936  6.802890  20.494418  5.333979
# 189590   49   9290   8.732355   1.129431  0.201518  10.063305  7.661287
# 189698   49   9564   8.693273   6.150535  9.190172  24.033979  5.813497
#
#         MaxELength     pMaxE   TopCRTE  BottomCRTE  FrontCRTE   BackCRTE  \
# ...

# %%
nueOutCRTMask = (nueOut.TopCRTE<=CRTEcut)&(nueOut.BottomCRTE<=CRTEcut)&(nueOut.FrontCRTE<=CRTEcut)&(nueOut.BackCRTE<=CRTEcut)& \
                (nueOut.LeftCRTE<=CRTEcut)&(nueOut.RightCRTE<=CRTEcut)
nueOutTPCMask = (nueOut.SignalVolEFrac>0.4)&(nueOut.MaxE>5.)&(nueOut.TotalE>52.)&(nueOut.SignalVolE>5)&(nueOut.TotalE>10)& \
                (nueOut.pMaxE<35)&(nueOut.MaxELength>15)
nueOutCut = nueOut[nueOutCRTMask&nueOutTPCMask]
nueOutCut
# Out:
# Empty DataFrame
# Columns: [Run, Event, FiducialE, PartConE, OutE, TotalE, MaxE, MaxELength, pMaxE, TopCRTE, BottomCRTE, FrontCRTE, BackCRTE, LeftCRTE, RightCRTE, SignalVolE, SignalVolEFrac, FiducialEFrac]
# Index: []

# %%
hogCRTMask = (hog.TopCRTE<=CRTEcut)&(hog.BottomCRTE<=CRTEcut)&(hog.FrontCRTE<=CRTEcut)&(hog.BackCRTE<=CRTEcut)& \
             (hog.LeftCRTE<=CRTEcut)&(hog.RightCRTE<=CRTEcut)
hogTPCMask = (hog.SignalVolEFrac>0.4)&(hog.MaxE>5.)&(hog.TotalE<52.)&(hog.SignalVolE>5)&(hog.TotalE>10)&(hog.pMaxE<35)& \
             (hog.MaxELength>15)
hogCut = hog[hogCRTMask&hogTPCMask]
hogCut
# Out:
# Empty DataFrame
# Columns: [Run, Event, FiducialE, PartConE, OutE, TotalE, MaxE, MaxELength, pMaxE, TopCRTE, BottomCRTE, FrontCRTE, BackCRTE, LeftCRTE, RightCRTE, SignalVolE, SignalVolEFrac, FiducialEFrac]
# Index: []

# %%
SF = 10.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(signalCut.MaxE, weights = np.full_like(signalCut.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41), color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC signal x10')
ax.hist(cosmicCut.MaxE, weights = np.full_like(cosmicCut.MaxE, fCosmic), bins = np.linspace(0, 40, 41), color = 'tab:orange',
        histtype = 'step', lw = 2, label = 'Cosmic with no muon>5cm')
ax.hist(brnCut.MaxE, weights = np.full_like(brnCut.MaxE, fBRN), bins = np.linspace(0, 40, 41), color = 'tab:green',
        histtype = 'step', lw = 2, linestyle = '-.', label = 'BRN')
ax.hist(nueOutCut.MaxE, weights = np.full_like(nueOutCut.MaxE, fNueOutFiducial), bins = np.linspace(0, 40, 41), color = 'tab:brown',
        histtype = 'step', lw = 2, linestyle = '-.', label = r'$\nu_e$-Ar CC outside')
ax.hist(hogCut.MaxE, weights = np.full_like(hogCut.MaxE, fHOG), bins = np.linspace(0, 40, 41), color = 'khaki',
        label = 'Hot-off Gas')
ax.set_xlabel( r'Leading Charged Particle Deposited Energy [MeV]', fontsize = 20 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 20 )
ax.tick_params(axis = 'x', labelsize = 20)
ax.tick_params(axis = 'y', labelsize = 20)
ax.set_xlim([5, 40])
#ax.set_ylim( [0, 30000])
ax.legend( fontsize = 18)
ax.set_title('TPC + CRT Selection', fontsize = 20)

ax.grid(":")
fig.savefig('CRTandTPCCutx10.pdf')

# %%
len(cosmicCut)
# Out:
# 26

# %%
len(signalCut)
# Out:
# 79443

# %%
len(nueOutCut)
# Out:
# 0

# %%
len(brnCut)
# Out:
# 208

# %%
26* fCosmic, 26*fCosmic/28, 79607*fNueSignal
# Out:
# (11232.0, 401.14285714285717, 92.742155)

# %%
np.sqrt(401)
# Out:
# 20.024984394500787

# %%
SF = 1.
SFLightDet = 1./28.
fig, ax = plt.subplots( figsize = (8, 6), layout = 'tight' )

ax.hist(signalCut.MaxE, weights = np.full_like(signalCut.MaxE, fNueSignal*SF), bins = np.linspace(0, 40, 41), color = 'paleturquoise',
        label = r'$\nu_e$-Ar CC signal')
ax.hist(cosmicCut.MaxE, weights = np.full_like(cosmicCut.MaxE, fCosmic*SFLightDet), bins = np.linspace(0, 40, 41), color = 'tab:orange',
        histtype = 'step', lw = 2, label = 'Cosmics')
ax.hist(brnCut.MaxE, weights = np.full_like(brnCut.MaxE, fBRN), bins = np.linspace(0, 40, 41), color = 'tab:green',
        histtype = 'step', lw = 2, linestyle = '-.', label = 'BRN')
ax.hist(nueOutCut.MaxE, weights = np.full_like(nueOutCut.MaxE, fNueOutFiducial), bins = np.linspace(0, 40, 41), color = 'tab:brown',
        histtype = 'step', lw = 2, linestyle = '-.', label = r'$\nu_e$-Ar CC outside')
ax.hist(hogCut.MaxE, weights = np.full_like(hogCut.MaxE, fBRN), bins = np.linspace(0, 40, 41), color = 'khaki',
        label = 'Hot-off Gas')

ax.set_xlabel( r'Deposited Energy of the Leading Charged Cluster [MeV]', fontsize = 20 )
ax.set_ylabel( r'Events/MeV/Year', fontsize = 20 )
ax.tick_params(axis = 'x', labelsize = 20)
ax.tick_params(axis = 'y', labelsize = 20)
ax.set_xlim([5, 40])
#ax.set_ylim( [0, 30000])
ax.legend( fontsize = 20)
ax.set_title(r'Simple Selection (TPC+CRT+$t_0$)', fontsize = 20)

ax.grid(":")
fig.savefig('CRTandLightandTPCCut.pdf')

# %%
np.sqrt(208)
# Out:
# 14.422205101855956
